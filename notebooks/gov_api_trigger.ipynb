# %% [markdown]
# # Gov API Trigger Graph
#
# This notebook is a lightweight trigger for `app/graphs/trigger.py`. Update the state below and run to validate inputs and call the registry trigger endpoint.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().resolve()
searched = set()
while not (project_root / "app").exists():
    if project_root in searched or project_root.parent == project_root:
        raise RuntimeError("Unable to locate project root containing the app package; open the notebook inside civic-app.")
    searched.add(project_root)
    project_root = project_root.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print(f"Using project root: {project_root}")

from app.graphs.trigger import create_trigger_graph

graph = create_trigger_graph()
trigger_state = {
    "metadata": {
        "trigger": {
            "api_id": "823b8951-6957-42a0-b7b2-c49c49e47ed4",
            "request": {
                "query": {
                    "date": "2024-01-01T12:00:00",
                },
                "useExampleDefaults": False,
            },
            # Optional: override request id or add headerOverrides/body if needed
            # "request_id": "job-20240620-001",
        }
    }
}
# Set dry_run=False to call the real registry at http://localhost:8080/api/v1/gov/apis/{apiId}/trigger
out = graph.invoke(trigger_state, config={"dry_run": True})
out
# Out:
# Using project root: /Users/sunyichun/PycharmProjects/civic-app
# /Users/sunyichun/PycharmProjects/civic-app/app/graphs/trigger.py:18: UserWarning: The 'config' parameter should be typed as 'RunnableConfig' or 'RunnableConfig | None', not 'GraphConfig | None'.
#   graph.add_node("api_trigger_agent", self.agent.run)
# {'trigger_response': {'status': 'SUCCESS',
#   'apiId': '823b8951-6957-42a0-b7b2-c49c49e47ed4',
#   'externalStatus': 200,
#   'invokedAt': '2026-01-11T08:20:14.966944Z',
#   'requestId': 'd4413e8a-a894-4903-a36a-097382f92734',
#   'responseBody': {'code': 0,
#    'data': {'stations': [{'id': 'S77',
#       'deviceId': 'S77',
#       'name': 'Alexandra Road',
#       'location': {'latitude': 1.2937, 'longitude': 103.8125}},
#      {'id': 'S109',
#       'deviceId': 'S109',
#       'name': 'Ang Mo Kio Avenue 5',
#       'location': {'latitude': 1.3764, 'longitude': 103.8492}},
#      {'id': 'S117',
#       'deviceId': 'S117',
#       'name': 'Banyan Road',
# ...
