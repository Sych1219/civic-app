# %% [markdown]
# # Gov API Catalog Graph
#
# This notebook is a lightweight trigger for `app/graphs/catalog.py`. Run it to compile and invoke the graph.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().resolve()
searched = set()
while not (project_root / "app").exists():
    if project_root in searched or project_root.parent == project_root:
        raise RuntimeError("Unable to locate project root containing the app package; open the notebook inside civic-app.")
    searched.add(project_root)
    project_root = project_root.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print(f"Using project root: {project_root}")

from app.graphs.catalog import create_catalog_graph

graph = create_catalog_graph()
query_state = {
    "metadata": {
        "catalog_query": {
            "description": "taxis",
            "page": 0,
            "size": 20,
            "sort": "createdAt,desc",
            "filters": {"httpMethod": "GET"},
        }
    }
}
# Set dry_run=False to call the real registry at http://localhost:8080/api/v1/gov/apis
out = graph.invoke(query_state, config={"dry_run": True})
out
# Out:
# Using project root: /Users/sunyichun/PycharmProjects/civic-app
# {'catalog_response': GovApiListResponse(items=[GovApiListItemResponse(id='25afbbc6-e03c-4244-81d3-b2af07df94e9', name='Taxi Availability', baseUrl='https://api.data.gov.sg/v1/transport/taxi-availability', httpMethod='GET', headers=[{'key': 'X-Api-Key', 'value': 'v2:382faf1568e57dfaaf399dcc7a0cfc23a6b05658730ca6baf72764f7aaa16e90:S0Ba4BHPYW_4lQQkE9olt3wXhtCdHT08', 'description': 'API key for higher rate limits'}], queryParams=[{'key': 'date_time', 'type': 'STRING', 'description': 'Date and time in SGT YYYY-MM-DD[T]HH:mm:ss (SGT)', 'exampleValue': '2024-01-01T12:00:00', 'children': []}], bodyParams=[], description='Get locations of available taxis in Singapore', status='REGISTERED', createdAt='2025-12-11T07:16:15.04559Z')], page=0, size=20, totalItems=1, totalPages=1, error=None, message=None, requestId='4a3f6ab1-1fbf-49bf-aabf-f127b034535f'),
#  'metadata': {'catalog_query': {'description': 'taxis',
#    'page': 0,
# ...
