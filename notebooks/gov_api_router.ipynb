# %% [markdown]
# # Gov API Router Graph
#
# This notebook routes chat-like input through the router graph to either register an API or invoke an existing one (catalog + trigger). Update the sample state as needed.

# %%
import sys
from pathlib import Path
from dotenv import load_dotenv

load_dotenv()

project_root = Path.cwd().resolve()
searched = set()
while not (project_root / "app").exists():
    if project_root in searched or project_root.parent == project_root:
        raise RuntimeError("Unable to locate project root containing the app package; open the notebook inside civic-app.")
    searched.add(project_root)
    project_root = project_root.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print(f"Using project root: {project_root}")

from app.graphs.router import create_router_graph

graph = create_router_graph()
# Example: asking for weather should route to catalog+trigger path
state = {
    "source_text": "How is the weather like Singapore in 2026-Jan-12 ?",
    # Optional explicit intent override: "register" or "invoke"
    # "metadata": {"intent": "invoke"},
}
# Set dry_run=False to actually call registry endpoints during trigger
out = graph.invoke(state, config={"dry_run": True})
out
# Out:
# Using project root: /Users/sunyichun/PycharmProjects/civic-app
# /Users/sunyichun/PycharmProjects/civic-app/app/graphs/router.py:48: UserWarning: The 'config' parameter should be typed as 'RunnableConfig' or 'RunnableConfig | None', not 'GraphConfig | None'.
#   graph.add_node("register_agent", self.register_agent.run)
# /Users/sunyichun/PycharmProjects/civic-app/app/graphs/router.py:49: UserWarning: The 'config' parameter should be typed as 'RunnableConfig' or 'RunnableConfig | None', not 'GraphConfig | None'.
#   graph.add_node("api_catalog_agent", self.catalog_agent.run)
# /Users/sunyichun/PycharmProjects/civic-app/app/graphs/router.py:50: UserWarning: The 'config' parameter should be typed as 'RunnableConfig' or 'RunnableConfig | None', not 'GraphConfig | None'.
#   graph.add_node("api_trigger_agent", self.trigger_agent.run)
# /Users/sunyichun/PycharmProjects/civic-app/app/graphs/router.py:51: UserWarning: The 'config' parameter should be typed as 'RunnableConfig' or 'RunnableConfig | None', not 'GraphConfig | None'.
#   graph.add_node("trigger_summary_agent", self.trigger_summary_agent.run)
# {'source_text': 'How is the weather like Singapore in 2026-Jan-12 ?',
#  'catalog_response': {'items': [{'id': '77f5f3f0-6665-408d-ac9d-d0788ffc7ef0',
#     'name': 'Retrieve 24 Hour Weather Forecast',
#     'baseUrl': 'https://api-open.data.gov.sg/v2/real-time/api/twenty-four-hr-forecast',
#     'httpMethod': 'GET',
#     'headers': [],
#     'queryParams': [{'key': 'date',
#       'type': 'STRING',
#       'description': 'SGT date (YYYY-MM-DD or YYYY-MM-DDTHH:MM:SS). Example: 2024-07-16 or 2024-07-16T23:59:00',
#       'exampleValue': '2024-07-16',
#       'children': []},
#      {'key': 'paginationToken',
#       'type': 'STRING',
#       'description': 'Pagination token for retrieving subsequent data pages (only exists when there is a next page available for requests with date filters).',
#       'exampleValue': None,
#       'children': []}],
#     'bodyParams': [],
#     'description': 'API to retrieve the latest 24 hour weather forecast from the National Environment Agency (NEA). TODO: Include details on response structure and error handling.',
#     'status': 'REGISTERED',
#     'createdAt': '2026-01-11T12:35:00.387759Z'},
#    {'id': '823b8951-6957-42a0-b7b2-c49c49e47ed4',
#     'name': 'Get Rainfall Readings',
#     'baseUrl': 'https://api-open.data.gov.sg/v2/real-time/api/rainfall',
#     'httpMethod': 'GET',
#     'headers': [],
#     'queryParams': [{'key': 'date',
#       'type': 'STRING',
#       'description': 'Format: YYYY-MM-DD or YYYY-MM-DDTHH:MM:SS (SGT). Example: 2024-07-16 or 2024-07-16T23:59:00',
#       'exampleValue': '2024-07-16',
#       'children': []},
#      {'key': 'paginationToken',
#       'type': 'STRING',
#       'description': 'Pagination token for retrieving subsequent data pages (only exists when there is a next page available for requests with date filters).',
#       'exampleValue': None,
#       'children': []}],
#     'bodyParams': [],
#     'description': 'Get rainfall readings across Singapore. Filter for specific date or date-time by providing date in query parameter. TODO: Include details on paginationToken usage.',
#     'status': 'REGISTERED',
#     'createdAt': '2026-01-10T08:09:53.670445Z'},
#    {'id': '25afbbc6-e03c-4244-81d3-b2af07df94e9',
#     'name': 'Taxi Availability',
#     'baseUrl': 'https://api.data.gov.sg/v1/transport/taxi-availability',
#     'httpMethod': 'GET',
#     'headers': [{'key': 'X-Api-Key',
#       'value': 'v2:382faf1568e57dfaaf399dcc7a0cfc23a6b05658730ca6baf72764f7aaa16e90:S0Ba4BHPYW_4lQQkE9olt3wXhtCdHT08',
#       'description': 'API key for higher rate limits'}],
#     'queryParams': [{'key': 'date_time',
#       'type': 'STRING',
#       'description': 'Date and time in SGT YYYY-MM-DD[T]HH:mm:ss (SGT)',
#       'exampleValue': '2024-01-01T12:00:00',
#       'children': []}],
#     'bodyParams': [],
#     'description': 'Get locations of available taxis in Singapore',
#     'status': 'REGISTERED',
#     'createdAt': '2025-12-11T07:16:15.04559Z'}],
#   'page': 0,
#   'size': 100,
#   'totalItems': 3,
#   'totalPages': 1,
#   'requestId': 'f51e5b9b-70ad-4b6b-a13a-c063ea1dc525'},
#  'trigger_response': {'status': 'SUCCESS',
#   'apiId': '77f5f3f0-6665-408d-ac9d-d0788ffc7ef0',
#   'externalStatus': 200,
#   'invokedAt': '2026-01-13T13:32:51.733633Z',
#   'requestId': '036f25c4-ef21-4495-87c0-73cbe9ef2dd4',
#   'responseBody': {'code': 0,
#    'data': {'records': [{'date': '2024-07-16',
#       'updatedTimestamp': '2024-07-16T23:11:18+08:00',
#       'general': {'temperature': {'low': 26,
#         'high': 33,
#         'unit': 'Degrees Celsius'},
#        'relativeHumidity': {'low': 50, 'high': 85, 'unit': 'Percentage'},
#        'forecast': {'code': 'FA', 'text': 'Fair (Day)'},
#        'validPeriod': {'start': '2024-07-17T00:00:00+08:00',
#         'end': '2024-07-18T00:00:00+08:00',
#         'text': '0 AM 17 Jul to 0 AM 18 Jul'},
#        'wind': {'speed': {'low': 15, 'high': 30}, 'direction': 'SSE'}},
#       'periods': [{'timePeriod': {'start': '2024-07-16T00:00:00+08:00',
#          'end': '2024-07-17T06:00:00+08:00',
#          'text': 'Midnight to 6 am 17 Jul'},
#         'regions': {'west': {'code': 'FN', 'text': 'Fair (Night)'},
#          'east': {'code': 'FN', 'text': 'Fair (Night)'},
#          'central': {'code': 'FN', 'text': 'Fair (Night)'},
#          'south': {'code': 'FN', 'text': 'Fair (Night)'},
#          'north': {'code': 'FN', 'text': 'Fair (Night)'}}},
#        {'timePeriod': {'start': '2024-07-16T06:00:00+08:00',
#          'end': '2024-07-17T12:00:00+08:00',
#          'text': '6 am to Midday 17 Jul'},
#         'regions': {'west': {'code': 'FA', 'text': 'Fair (Day)'},
#          'east': {'code': 'FA', 'text': 'Fair (Day)'},
#          'central': {'code': 'FA', 'text': 'Fair (Day)'},
#          'south': {'code': 'FA', 'text': 'Fair (Day)'},
#          'north': {'code': 'FA', 'text': 'Fair (Day)'}}},
#        {'timePeriod': {'start': '2024-07-16T12:00:00+08:00',
#          'end': '2024-07-17T18:00:00+08:00',
#          'text': 'Midday to 6 pm 17 Jul'},
#         'regions': {'west': {'code': 'FA', 'text': 'Fair (Day)'},
#          'east': {'code': 'FA', 'text': 'Fair (Day)'},
#          'central': {'code': 'FA', 'text': 'Fair (Day)'},
#          'south': {'code': 'FA', 'text': 'Fair (Day)'},
#          'north': {'code': 'FA', 'text': 'Fair (Day)'}}},
#        {'timePeriod': {'start': '2024-07-16T18:00:00+08:00',
#          'end': '2024-07-17T00:00:00+08:00',
#          'text': '6 pm to Midnight 17 Jul'},
#         'regions': {'west': {'code': 'FN', 'text': 'Fair (Night)'},
#          'east': {'code': 'FN', 'text': 'Fair (Night)'},
#          'central': {'code': 'FN', 'text': 'Fair (Night)'},
#          'south': {'code': 'FN', 'text': 'Fair (Night)'},
#          'north': {'code': 'FN', 'text': 'Fair (Night)'}}}],
#       'timestamp': '2024-07-16T23:00:00+08:00'},
#      {'date': '2024-07-16',
#       'updatedTimestamp': '2024-07-16T17:50:59+08:00',
#       'general': {'temperature': {'low': 26,
#         'high': 33,
#         'unit': 'Degrees Celsius'},
#        'relativeHumidity': {'low': 50, 'high': 85, 'unit': 'Percentage'},
#        'forecast': {'code': 'WD', 'text': 'Windy'},
#        'validPeriod': {'start': '2024-07-16T18:00:00+08:00',
#         'end': '2024-07-17T18:00:00+08:00',
#         'text': '6 PM 16 Jul to 6 PM 17 Jul'},
#        'wind': {'speed': {'low': 15, 'high': 30}, 'direction': 'SSE'}},
#       'periods': [{'timePeriod': {'start': '2024-07-16T18:00:00+08:00',
#          'end': '2024-07-17T06:00:00+08:00',
#          'text': '6 pm 16 Jul to 6 am 17 Jul'},
#         'regions': {'west': {'code': 'WD', 'text': 'Windy'},
#          'east': {'code': 'WD', 'text': 'Windy'},
#          'central': {'code': 'WD', 'text': 'Windy'},
#          'south': {'code': 'WD', 'text': 'Windy'},
#          'north': {'code': 'WD', 'text': 'Windy'}}},
#        {'timePeriod': {'start': '2024-07-16T06:00:00+08:00',
#          'end': '2024-07-17T12:00:00+08:00',
#          'text': '6 am to Midday 17 Jul'},
#         'regions': {'west': {'code': 'FA', 'text': 'Fair (Day)'},
#          'east': {'code': 'FA', 'text': 'Fair (Day)'},
#          'central': {'code': 'FA', 'text': 'Fair (Day)'},
#          'south': {'code': 'FA', 'text': 'Fair (Day)'},
#          'north': {'code': 'FA', 'text': 'Fair (Day)'}}},
#        {'timePeriod': {'start': '2024-07-16T12:00:00+08:00',
#          'end': '2024-07-17T18:00:00+08:00',
#          'text': 'Midday to 6 pm 17 Jul'},
#         'regions': {'west': {'code': 'FA', 'text': 'Fair (Day)'},
#          'east': {'code': 'FA', 'text': 'Fair (Day)'},
#          'central': {'code': 'FA', 'text': 'Fair (Day)'},
#          'south': {'code': 'FA', 'text': 'Fair (Day)'},
#          'north': {'code': 'FA', 'text': 'Fair (Day)'}}}],
#       'timestamp': '2024-07-16T17:39:00+08:00'},
#      {'date': '2024-07-16',
#       'updatedTimestamp': '2024-07-16T16:01:13+08:00',
#       'general': {'temperature': {'low': 26,
#         'high': 33,
#         'unit': 'Degrees Celsius'},
#        'relativeHumidity': {'low': 50, 'high': 85, 'unit': 'Percentage'},
#        'forecast': {'code': 'WD', 'text': 'Windy'},
#        'validPeriod': {'start': '2024-07-16T12:00:00+08:00',
#         'end': '2024-07-17T12:00:00+08:00',
#         'text': '12 PM 16 Jul to 12 PM 17 Jul'},
#        'wind': {'speed': {'low': 15, 'high': 30}, 'direction': 'S'}},
#       'periods': [{'timePeriod': {'start': '2024-07-16T12:00:00+08:00',
#          'end': '2024-07-16T18:00:00+08:00',
#          'text': 'Midday to 6 pm 16 Jul'},
#         'regions': {'west': {'code': 'WD', 'text': 'Windy'},
#          'east': {'code': 'WD', 'text': 'Windy'},
#          'central': {'code': 'WD', 'text': 'Windy'},
#          'south': {'code': 'WD', 'text': 'Windy'},
#          'north': {'code': 'WD', 'text': 'Windy'}}},
#        {'timePeriod': {'start': '2024-07-16T18:00:00+08:00',
#          'end': '2024-07-17T06:00:00+08:00',
#          'text': '6 pm 16 Jul to 6 am 17 Jul'},
#         'regions': {'west': {'code': 'WD', 'text': 'Windy'},
#          'east': {'code': 'WD', 'text': 'Windy'},
#          'central': {'code': 'WD', 'text': 'Windy'},
#          'south': {'code': 'WD', 'text': 'Windy'},
#          'north': {'code': 'WD', 'text': 'Windy'}}},
#        {'timePeriod': {'start': '2024-07-16T06:00:00+08:00',
#          'end': '2024-07-17T12:00:00+08:00',
#          'text': '6 am to Midday 17 Jul'},
#         'regions': {'west': {'code': 'WD', 'text': 'Windy'},
#          'east': {'code': 'WD', 'text': 'Windy'},
#          'central': {'code': 'WD', 'text': 'Windy'},
#          'south': {'code': 'WD', 'text': 'Windy'},
#          'north': {'code': 'WD', 'text': 'Windy'}}}],
#       'timestamp': '2024-07-16T15:50:00+08:00'},
#      {'date': '2024-07-16',
#       'updatedTimestamp': '2024-07-16T15:01:09+08:00',
#       'general': {'temperature': {'low': 26,
#         'high': 34,
#         'unit': 'Degrees Celsius'},
#        'relativeHumidity': {'low': 50, 'high': 85, 'unit': 'Percentage'},
#        'forecast': {'code': 'WD', 'text': 'Windy'},
#        'validPeriod': {'start': '2024-07-16T12:00:00+08:00',
#         'end': '2024-07-17T12:00:00+08:00',
#         'text': '12 PM 16 Jul to 12 PM 17 Jul'},
#        'wind': {'speed': {'low': 15, 'high': 30}, 'direction': 'S'}},
#       'periods': [{'timePeriod': {'start': '2024-07-16T12:00:00+08:00',
#          'end': '2024-07-16T18:00:00+08:00',
#          'text': 'Midday to 6 pm 16 Jul'},
#         'regions': {'west': {'code': 'WD', 'text': 'Windy'},
#          'east': {'code': 'WD', 'text': 'Windy'},
#          'central': {'code': 'WD', 'text': 'Windy'},
#          'south': {'code': 'WD', 'text': 'Windy'},
#          'north': {'code': 'WD', 'text': 'Windy'}}},
#        {'timePeriod': {'start': '2024-07-16T18:00:00+08:00',
#          'end': '2024-07-17T06:00:00+08:00',
#          'text': '6 pm 16 Jul to 6 am 17 Jul'},
#         'regions': {'west': {'code': 'WD', 'text': 'Windy'},
#          'east': {'code': 'WD', 'text': 'Windy'},
#          'central': {'code': 'WD', 'text': 'Windy'},
#          'south': {'code': 'WD', 'text': 'Windy'},
#          'north': {'code': 'WD', 'text': 'Windy'}}},
#        {'timePeriod': {'start': '2024-07-16T06:00:00+08:00',
#          'end': '2024-07-17T12:00:00+08:00',
#          'text': '6 am to Midday 17 Jul'},
#         'regions': {'west': {'code': 'WD', 'text': 'Windy'},
#          'east': {'code': 'WD', 'text': 'Windy'},
#          'central': {'code': 'WD', 'text': 'Windy'},
#          'south': {'code': 'WD', 'text': 'Windy'},
#          'north': {'code': 'WD', 'text': 'Windy'}}}],
#       'timestamp': '2024-07-16T14:52:00+08:00'},
#      {'date': '2024-07-16',
#       'updatedTimestamp': '2024-07-16T12:01:04+08:00',
#       'general': {'temperature': {'low': 26,
#         'high': 34,
#         'unit': 'Degrees Celsius'},
#        'relativeHumidity': {'low': 50, 'high': 85, 'unit': 'Percentage'},
#        'forecast': {'code': 'SH', 'text': 'Showers'},
#        'validPeriod': {'start': '2024-07-16T12:00:00+08:00',
#         'end': '2024-07-17T12:00:00+08:00',
#         'text': '12 PM 16 Jul to 12 PM 17 Jul'},
#        'wind': {'speed': {'low': 15, 'high': 30}, 'direction': 'S'}},
#       'periods': [{'timePeriod': {'start': '2024-07-16T12:00:00+08:00',
#          'end': '2024-07-16T18:00:00+08:00',
#          'text': 'Midday to 6 pm 16 Jul'},
#         'regions': {'west': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'east': {'code': 'SH', 'text': 'Showers'},
#          'central': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'south': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'north': {'code': 'SH', 'text': 'Showers'}}},
#        {'timePeriod': {'start': '2024-07-16T18:00:00+08:00',
#          'end': '2024-07-17T06:00:00+08:00',
#          'text': '6 pm 16 Jul to 6 am 17 Jul'},
#         'regions': {'west': {'code': 'PN', 'text': 'Partly Cloudy (Night)'},
#          'east': {'code': 'PN', 'text': 'Partly Cloudy (Night)'},
#          'central': {'code': 'PN', 'text': 'Partly Cloudy (Night)'},
#          'south': {'code': 'PN', 'text': 'Partly Cloudy (Night)'},
#          'north': {'code': 'PN', 'text': 'Partly Cloudy (Night)'}}},
#        {'timePeriod': {'start': '2024-07-16T06:00:00+08:00',
#          'end': '2024-07-17T12:00:00+08:00',
#          'text': '6 am to Midday 17 Jul'},
#         'regions': {'west': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'east': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'central': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'south': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'north': {'code': 'PC', 'text': 'Partly Cloudy (Day)'}}}],
#       'timestamp': '2024-07-16T11:55:00+08:00'},
#      {'date': '2024-07-16',
#       'updatedTimestamp': '2024-07-17T16:35:15+08:00',
#       'general': {'temperature': {'low': 26,
#         'high': 34,
#         'unit': 'Degrees Celsius'},
#        'relativeHumidity': {'low': 50, 'high': 85, 'unit': 'Percentage'},
#        'forecast': {'code': 'SH', 'text': 'Showers'},
#        'validPeriod': {'start': '2024-07-16T06:00:00+08:00',
#         'end': '2024-07-17T06:00:00+08:00',
#         'text': '6 AM 16 Jul to 6 AM 17 Jul'},
#        'wind': {'speed': {'low': 15, 'high': 30}, 'direction': 'S'}},
#       'periods': [{'timePeriod': {'start': '2024-07-16T06:00:00+08:00',
#          'end': '2024-07-16T12:00:00+08:00',
#          'text': '6 am to Midday 16 Jul'},
#         'regions': {'west': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'east': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'central': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'south': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'north': {'code': 'PC', 'text': 'Partly Cloudy (Day)'}}},
#        {'timePeriod': {'start': '2024-07-16T12:00:00+08:00',
#          'end': '2024-07-16T18:00:00+08:00',
#          'text': 'Midday to 6 pm 16 Jul'},
#         'regions': {'west': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'east': {'code': 'SH', 'text': 'Showers'},
#          'central': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'south': {'code': 'PC', 'text': 'Partly Cloudy (Day)'},
#          'north': {'code': 'SH', 'text': 'Showers'}}},
#        {'timePeriod': {'start': '2024-07-16T18:00:00+08:00',
#          'end': '2024-07-17T06:00:00+08:00',
#          'text': '6 pm 16 Jul to 6 am 17 Jul'},
#         'regions': {'west': {'code': 'PN', 'text': 'Partly Cloudy (Night)'},
#          'east': {'code': 'PN', 'text': 'Partly Cloudy (Night)'},
#          'central': {'code': 'PN', 'text': 'Partly Cloudy (Night)'},
#          'south': {'code': 'PN', 'text': 'Partly Cloudy (Night)'},
#          'north': {'code': 'PN', 'text': 'Partly Cloudy (Night)'}}}],
#       'timestamp': '2024-07-16T10:52:00+08:00'},
#      {'date': '2024-07-16',
#       'updatedTimestamp': '2024-07-17T16:35:14+08:00',
#       'general': {'temperature': {'low': 26,
#         'high': 34,
#         'unit': 'Degrees Celsius'},
#        'relativeHumidity': {'low': 50, 'high': 85, 'unit': 'Percentage'},
#        'forecast': {'code': 'FA', 'text': 'Fair (Day)'},
#        'validPeriod': {'start': '2024-07-16T06:00:00+08:00',
#         'end': '2024-07-17T06:00:00+08:00',
#         'text': '6 AM 16 Jul to 6 AM 17 Jul'},
#        'wind': {'speed': {'low': 15, 'high': 30}, 'direction': 'S'}},
#       'periods': [{'timePeriod': {'start': '2024-07-16T06:00:00+08:00',
#          'end': '2024-07-16T12:00:00+08:00',
#          'text': '6 am to Midday 16 Jul'},
#         'regions': {'west': {'code': 'FA', 'text': 'Fair (Day)'},
#          'east': {'code': 'FA', 'text': 'Fair (Day)'},
#          'central': {'code': 'FA', 'text': 'Fair (Day)'},
#          'south': {'code': 'FA', 'text': 'Fair (Day)'},
#          'north': {'code': 'FA', 'text': 'Fair (Day)'}}},
#        {'timePeriod': {'start': '2024-07-16T12:00:00+08:00',
#          'end': '2024-07-16T18:00:00+08:00',
#          'text': 'Midday to 6 pm 16 Jul'},
#         'regions': {'west': {'code': 'FA', 'text': 'Fair (Day)'},
#          'east': {'code': 'FA', 'text': 'Fair (Day)'},
#          'central': {'code': 'FA', 'text': 'Fair (Day)'},
#          'south': {'code': 'FA', 'text': 'Fair (Day)'},
#          'north': {'code': 'FA', 'text': 'Fair (Day)'}}},
#        {'timePeriod': {'start': '2024-07-16T18:00:00+08:00',
#          'end': '2024-07-17T06:00:00+08:00',
#          'text': '6 pm 16 Jul to 6 am 17 Jul'},
#         'regions': {'west': {'code': 'FN', 'text': 'Fair (Night)'},
#          'east': {'code': 'FN', 'text': 'Fair (Night)'},
#          'central': {'code': 'FN', 'text': 'Fair (Night)'},
#          'south': {'code': 'FN', 'text': 'Fair (Night)'},
#          'north': {'code': 'FN', 'text': 'Fair (Night)'}}}],
#       'timestamp': '2024-07-16T08:59:00+08:00'},
#      {'date': '2024-07-16',
#       'updatedTimestamp': '2024-07-17T16:39:39+08:00',
#       'general': {'temperature': {'low': 25,
#         'high': 34,
#         'unit': 'Degrees Celsius'},
#        'relativeHumidity': {'low': 50, 'high': 85, 'unit': 'Percentage'},
#        'forecast': {'code': 'FA', 'text': 'Fair (Day)'},
#        'validPeriod': {'start': '2024-07-16T06:00:00+08:00',
#         'end': '2024-07-17T06:00:00+08:00',
#         'text': '6 AM 16 Jul to 6 AM 17 Jul'},
#        'wind': {'speed': {'low': 15, 'high': 30}, 'direction': 'S'}},
#       'periods': [{'timePeriod': {'start': '2024-07-16T06:00:00+08:00',
#          'end': '2024-07-16T12:00:00+08:00',
#          'text': '6 am to Midday 16 Jul'},
#         'regions': {'west': {'code': 'FA', 'text': 'Fair (Day)'},
#          'east': {'code': 'FA', 'text': 'Fair (Day)'},
#          'central': {'code': 'FA', 'text': 'Fair (Day)'},
#          'south': {'code': 'FA', 'text': 'Fair (Day)'},
#          'north': {'code': 'FA', 'text': 'Fair (Day)'}}},
#        {'timePeriod': {'start': '2024-07-16T12:00:00+08:00',
#          'end': '2024-07-16T18:00:00+08:00',
#          'text': 'Midday to 6 pm 16 Jul'},
#         'regions': {'west': {'code': 'FA', 'text': 'Fair (Day)'},
#          'east': {'code': 'FA', 'text': 'Fair (Day)'},
#          'central': {'code': 'FA', 'text': 'Fair (Day)'},
#          'south': {'code': 'FA', 'text': 'Fair (Day)'},
#          'north': {'code': 'FA', 'text': 'Fair (Day)'}}},
#        {'timePeriod': {'start': '2024-07-16T18:00:00+08:00',
#          'end': '2024-07-17T06:00:00+08:00',
#          'text': '6 pm 16 Jul to 6 am 17 Jul'},
#         'regions': {'west': {'code': 'FN', 'text': 'Fair (Night)'},
#          'east': {'code': 'FN', 'text': 'Fair (Night)'},
#          'central': {'code': 'FN', 'text': 'Fair (Night)'},
#          'south': {'code': 'FN', 'text': 'Fair (Night)'},
#          'north': {'code': 'FN', 'text': 'Fair (Night)'}}}],
#       'timestamp': '2024-07-16T05:32:00+08:00'}]},
#    'errorMsg': ''}},
#  'trigger_request': {'useExampleDefaults': True},
#  'trigger_summary': 'The API response does not provide weather information for Singapore on January 12, 2026. Instead, it contains data for July 16, 2024, indicating temperatures between 26°C and 34°C, with varying forecasts including "Fair (Day)" and "Windy." Unfortunately, the specific weather details for the requested date are not available.',
#  'metadata': {'catalog_query': {'page': 0, 'size': 100},
#   'trigger': {'api_id': '77f5f3f0-6665-408d-ac9d-d0788ffc7ef0',
#    'request': {'useExampleDefaults': True}}}}
